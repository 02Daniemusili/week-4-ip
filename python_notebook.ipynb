# %% [markdown]
# <a href="https://colab.research.google.com/github/12345997/week-4-ip/blob/main/python_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #What to check Autolib.csv
# #below is  link to our dataset.[link]([http://bit.ly/autolib_dataset])

# %% [markdown]
# * Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
#
# *Bonus Questions (Optional)
#
# * What is the most popular hour for returning cars?
#
# * What station is the most popular?
# Overall?
#
# *At the most popular picking hour?
#
# *What postal code is the most popular for picking up Blue cars? Does the most
#
# popular station belong to that postal code?
#
# Overall?
# *At the most popular picking hour?
#
# *Do the results change if you consider Utilib and Utilib 1.4 instead of Blue cars?

# %% [markdown]
# #importing our libraries

# %%
# Importing the pandas library
# 
import pandas as pd

# Importing the numpy library
#
import numpy as np

# %% [markdown]
# #The dataset we will use contains information about car charging time intervals
#
#
#
# *   Dataset link for download or access:(http://bit.ly/autolib_dataset

# %%
# Let's read the data from the CSV file and create the dataframe to be used
# 
Autolib=pd.read_csv("/content/Autolib_dataset .csv")
Autolib
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]

# %%
# Let's preview the first 10 rows of our data
# 
Autolib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
#  15  Scheduled at         47 non-null     object
#  16  Slots                5000 non-null   int64
#  17  Station type         5000 non-null   object
#  18  Status               5000 non-null   object
#  19  Subscription status  5000 non-null   object
#  20  year                 5000 non-null   int64
#  21  month                5000 non-null   int64
#  22  day                  5000 non-null   int64
#  23  hour                 5000 non-null   int64
#  24  minute               5000 non-null   int64
# dtypes: int64(12), object(13)
# memory usage: 976.7+ KB

# %%
#Checking if there is any missing value in dataframe as a whole
Autolib.isnull()
# Out:
#       Address   Cars  Bluecar counter  ...    day   hour  minute
# 0       False  False            False  ...  False  False   False
# 1       False  False            False  ...  False  False   False
# 2       False  False            False  ...  False  False   False
# 3       False  False            False  ...  False  False   False
# 4       False  False            False  ...  False  False   False
# ...       ...    ...              ...  ...    ...    ...     ...
# 4995    False  False            False  ...  False  False   False
# 4996    False  False            False  ...  False  False   False
# 4997    False  False            False  ...  False  False   False
# 4998    False  False            False  ...  False  False   False
# 4999    False  False            False  ...  False  False   False
#
# [5000 rows x 25 columns]

# %% [markdown]
# #Data cleaning

# %%
#Let's remove use the str.strip function on the respective column name to strip the leading and trailing space 
# Also remove white spaces and convert the column names to lower case

Autolib.columns = Autolib.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
Autolib
# Out:
#                                  address  cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]

# %%
#Dropping the irrelevant columns
Autolib.drop(["displayed_comment","scheduled_at"], axis = 1, inplace = True)
Autolib
# Out:
#                                  address  cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 23 columns]

# %%
#Checking how many missing values there are across each column
Autolib.isnull().sum()
# Out:
# Address                0
# Bluecar counter        0
# Utilib counter         0
# Utilib 1.4 counter     0
# Charge Slots           0
# Charging Status        0
# City                   0
# ID                     0
# Kind                   0
# Postal code            0
# Public name            0
# Rental status          0
# Station type           0
# Status                 0
# Subscription status    0
# year                   0
# month                  0
# day                    0
# hour                   0
# minute                 0
# dtype: int64

# %%
from datetime import time

# %%
#converting hour clumn to string
Autolib['hour'] = Autolib['hour'].astype(str)

# %%
#converting minute column to string
Autolib['minute'] = Autolib['minute'].astype(str)

# %%
#
Autolib["Time"]=Autolib['hour']+":"+Autolib['minute']
Autolib
# Out:
#                                  address  cars  ...  minute   Time
# 0                    2 Avenue de Suffren     0  ...      43  11:43
# 1              145 Rue Raymond Losserand     6  ...      24   7:24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...      14  20:14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...      37   4:37
# 4     6 avenue de la Porte de Champerret     3  ...      23  17:23
# ...                                  ...   ...  ...     ...    ...
# 4995                 8 avenue M̩nelotte     2  ...      26  11:26
# 4996                   37 rue de Dantzig     4  ...      56  16:56
# 4997                      142 rue du Bac     1  ...       1    7:1
# 4998         2 avenue du Val de Fontenay     2  ...      27  17:27
# 4999                 5 Rue Henry Brisson     4  ...       2   10:2
#
# [5000 rows x 24 columns]

# %%
Autolib.head(3)
# Out:
#                             address  cars  bluecar_counter  ...  hour  minute   Time
# 0               2 Avenue de Suffren     0                0  ...    11      43  11:43
# 1         145 Rue Raymond Losserand     6                6  ...     7      24   7:24
# 2  2 Avenue John Fitzgerald Kennedy     3                3  ...    20      14  20:14
#
# [3 rows x 24 columns]

# %%
#importing matplotlib in our dataset
import matplotlib.pyplot as plt 
% matplotlib inline

# %%
Autolib.describe()
# Out:
#               cars  bluecar_counter  ...   month          day
# count  5000.000000      5000.000000  ...  5000.0  5000.000000
# mean      2.333600         2.333600  ...     4.0     4.941600
# std       2.035274         2.035274  ...     0.0     2.597063
# min       0.000000         0.000000  ...     4.0     1.000000
# 25%       0.000000         0.000000  ...     4.0     3.000000
# 50%       2.000000         2.000000  ...     4.0     5.000000
# 75%       4.000000         4.000000  ...     4.0     7.000000
# max       7.000000         7.000000  ...     4.0     9.000000
#
# [8 rows x 10 columns]

# %%
#First import seaborn library
import seaborn as sns

# %%
Q1 = Autolib.quantile(0.25)
Q3 = Autolib.quantile(0.75)

IQR = Q3 - Q1


(Autolib < (Q1 - 1.5 * IQR)) |(Autolib > (Q3 + 1.5 * IQR))


# The two commented lines of code below can be used to drop the outliers but for now I will not drop them since the data
#does not seem to have extreem outliers.This is due to the range of each column.

# Autolib_no_outlier = Electric[~((Autolib < (Q1 - 1.5 * IQR)) | (Autolib > (Q3 + 1.5 * IQR))).any(axis = 1)]

# print(Autolib_no_outlier)
# Out:
#        Time  address  ...  utilib_counter   year
# 0     False    False  ...           False  False
# 1     False    False  ...           False  False
# 2     False    False  ...           False  False
# 3     False    False  ...            True  False
# 4     False    False  ...           False  False
# ...     ...      ...  ...             ...    ...
# 4995  False    False  ...           False  False
# 4996  False    False  ...           False  False
# 4997  False    False  ...           False  False
# 4998  False    False  ...           False  False
# 4999  False    False  ...           False  False
#
# [5000 rows x 24 columns]

# %%
#Plot the boxplot using one column .On this case we used bluecar_counter
Autolib.boxplot(column =['bluecar_counter',"utilib_counter","utilib_1.4_counter"], grid = False)

# %%
#joining the year, month and day columns
Autolib["Date"]=pd.to_datetime((Autolib.year*10000+Autolib.month*100+Autolib.day).apply(str),format="%Y%m%d")
Autolib.head()
# Out:
#                               Address  Bluecar counter  ...   Time       Date
# 0                 2 Avenue de Suffren                0  ...  11:43 2018-04-08
# 1           145 Rue Raymond Losserand                6  ...   7:24 2018-04-06
# 2    2 Avenue John Fitzgerald Kennedy                3  ...  20:14 2018-04-03
# 3              51 Rue Eug̬ne Oudin̩                3  ...   4:37 2018-04-04
# 4  6 avenue de la Porte de Champerret                3  ...  17:23 2018-04-08
#
# [5 rows x 22 columns]

# %%
#At this stage ,we check if the its true that the column cars and bluecar counter are the same as explained in the data glossary
def  number(row):
  if row['cars'] == row['bluecar_counter']:
    return 'True'
  else:
      return 'False'
#Apply the lambda function and create a new column with the new row
Autolib['Verifier_column']=Autolib.apply (lambda row: number(row), axis=1)
Autolib.head(10)
# Out:
#                               address  cars  ...   Time  Verifier_column
# 0                 2 Avenue de Suffren     0  ...  11:43             True
# 1           145 Rue Raymond Losserand     6  ...   7:24             True
# 2    2 Avenue John Fitzgerald Kennedy     3  ...  20:14             True
# 3              51 Rue Eug̬ne Oudin̩     3  ...   4:37             True
# 4  6 avenue de la Porte de Champerret     3  ...  17:23             True
# 5                8 Boulevard Voltaire     0  ...    7:2             True
# 6                      37 rue Leblanc     0  ...  18:20             True
# 7         17 Rue des Luaps Prolong̩e     3  ...  22:13             True
# 8               34 avenue Jean Moulin     1  ...  22:58             True
# 9        41 boulevard de Rochechouart     6  ...   15:2             True
#
# [10 rows x 25 columns]

# %%
#This is to verify that the two columns are true.
len(Autolib[Autolib['Verifier_column'] == 'True'])
# Out:
# 5000

# %%
#checking the distribution of the columns data using histogram
#if the data is positively skewed and there is presence of outliers
Autolib.hist(column=["bluecar_counter","utilib_counter","utilib_1.4_counter"])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f47f4e8d5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f47f4e45b10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f47f4e051d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f47f4db9850>]],
#       dtype=object)

# %% [markdown]
# #consistency

# %%
#To check if our dataset has duplicate values, we use the duplicated function
Autolib.duplicated().sum()

#There are zero duplicates
# Out:
# 0

# %% [markdown]
# #checking data uniformity

# %%
# We had cleaned the data above. To confirm data types
Autolib.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   address              5000 non-null   object
#  1   cars                 5000 non-null   int64
#  2   bluecar_counter      5000 non-null   int64
#  3   utilib_counter       5000 non-null   int64
#  4   utilib_1.4_counter   5000 non-null   int64
#  5   charge_slots         5000 non-null   int64
#  6   charging_status      5000 non-null   object
#  7   city                 5000 non-null   object
#  8   id                   5000 non-null   object
#  9   kind                 5000 non-null   object
#  10  geo_point            5000 non-null   object
#  11  postal_code          5000 non-null   int64
#  12  public_name          5000 non-null   object
#  13  rental_status        5000 non-null   object
#  14  slots                5000 non-null   int64
#  15  station_type         5000 non-null   object
#  16  status               5000 non-null   object
#  17  subscription_status  5000 non-null   object
#  18  year                 5000 non-null   int64
#  19  month                5000 non-null   int64
#  20  day                  5000 non-null   int64
#  21  hour                 5000 non-null   object
#  22  minute               5000 non-null   object
#  23  Time                 5000 non-null   object
#  24  Verifier_column      5000 non-null   object
# dtypes: int64(10), object(15)
# memory usage: 976.7+ KB

# %% [markdown]
# #Data analysysis

# %% [markdown]
# ##Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.

# %%
#identifyng the most popular hour for picking a bluecar in paris
new_Autolib_paris = Autolib[Autolib['city'] =='Paris'] 
new_Autolib_paris

#Group by hour to find the most used bluecars
Paris_hour = new_Autolib_paris.groupby(['hour'])['bluecar_counter'].sum().diff().sort_values(ascending = False)
Paris_hour.head(1)
# Out:
# hour
# 21    119.0
# Name: bluecar_counter, dtype: float64

# %%
#Creating a new column where we find the difference in the number of bluecars at the station/counter

Autolib['bluecar_Diff'] = Autolib['bluecar_counter'].diff()
Autolib.head()
#uncommenting the lines below will give you the maximum  bluecar_counter
#Autolib.sort_values(by=(['bluecar_Diff']), inplace=True)
#Autolib.max()
# Out:
#                             address  cars  ...  Verifier_column  bluecar_Diff
# 0               2 Avenue de Suffren     0  ...             True           NaN
# 4330                1 rue de Sevran     0  ...             True           0.0
# 1180         137 Rue des Pyr̩n̩es     0  ...             True           0.0
# 4328                31 avenue Hoche     0  ...             True           0.0
# 4234  24 rue du Pont Louis-Philippe     0  ...             True           0.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ##popular hour for returning cars?

# %%
#which is the most popular hour for returning cars?


Autolib['total_cars'] = Autolib.iloc[:,2:4].sum(axis = 1)
Autolib.head()
# Out:
#                             address  cars  ...  bluecar_Diff  total_cars
# 0               2 Avenue de Suffren     0  ...           NaN           0
# 4330                1 rue de Sevran     0  ...           0.0           0
# 1180         137 Rue des Pyr̩n̩es     0  ...           0.0           0
# 4328                31 avenue Hoche     0  ...           0.0           0
# 4234  24 rue du Pont Louis-Philippe     0  ...           0.0           0
#
# [5 rows x 27 columns]

# %%
cars = Autolib.groupby(['hour'])['total_cars'].sum().diff().sort_values(ascending=True)
cars.head(1)
#The most popular hour for returning is hour 14hrs. Has the highest positive total
# Out:
# hour
# 20   -154.0
# Name: total_cars, dtype: float64

# %% [markdown]
# #which was the most popular station?

# %%
#What station is the most popular?
# Overall?
#At the most popular picking hour?

Popular_station = Autolib.groupby(['id','hour'])['total_cars'].sum().sort_values(ascending = False)
Popular_station.head()
# Out:
# id                                   hour
# courbevoie-paix-2                    2       15
# paris-portedevilliers-28             8       15
# fontenayauxroses-divisionleclerc-31  7       14
# saintouen-louisblanc-35              2       14
# velizyvillacoublay-pauldautier-2     13      14
# Name: total_cars, dtype: int64

# %%
# Finding the most popular hour
popular_hour = Autolib.groupby(['hour'])['total_cars'].sum().diff().sort_values(ascending = False)
popular_hour.head(1)
# Out:
# hour
# 2    179.0
# Name: total_cars, dtype: float64

# %% [markdown]
# # What station is the most popular, At the most popular picking hour?

# %%
Autolib.head()
# Out:
#                             address  cars  ...  bluecar_Diff  total_cars
# 0               2 Avenue de Suffren     0  ...           NaN           0
# 4330                1 rue de Sevran     0  ...           0.0           0
# 1180         137 Rue des Pyr̩n̩es     0  ...           0.0           0
# 4328                31 avenue Hoche     0  ...           0.0           0
# 4234  24 rue du Pont Louis-Philippe     0  ...           0.0           0
#
# [5 rows x 27 columns]

# %%
# Subsetting the most popular picking hour
Autolib[(Autolib['kind'] == 'STATION') & (Autolib['status'] == 'ok') & (Autolib['hour'] == 14)].groupby('public_name')['public_name'].count().sort_values(ascending= False)
Autolib
Hour = Autolib[(Autolib.hour =!14)]
Hour.head()
# Out:
# Empty DataFrame
# Columns: [address, cars, bluecar_counter, utilib_counter, utilib_1.4_counter, charge_slots, charging_status, city, id, kind, geo_point, postal_code, public_name, rental_status, slots, station_type, status, subscription_status, year, month, day, hour, minute, Time, Verifier_column, bluecar_Diff, total_cars]
# Index: []

# %%
#most popular hour station
popular_station_hour = Hour.groupby(['public_name'])['total_cars'].sum().sort_values(ascending = False)
popular_station_hour.head(4)
# Out:
# public_name
# Fontenay-aux-Roses/Robert Marchand/32     50
# Le Plessis-Robinson/Galil̩e/16           49
# Fontenay-aux-Roses/Lombard/20             48
# Fontenay-aux-Roses/Division Leclerc/31    45
# Name: total_cars, dtype: int64

# %% [markdown]
# #checking for the most popular city

# %%
#checking for the most popular city
popular_city = Autolib.groupby(['city'])['total_cars'].sum().sort_values(ascending = False)
popular_city.head()
# Out:
# city
# Paris                  5293
# Nanterre                473
# Issy-les-Moulineaux     325
# Cr̩teil                323
# Rueil-Malmaison         305
# Name: total_cars, dtype: int64

# %%
#most popular postal code
popular_code = Autolib.groupby(['hour','postal_code'])['bluecar_counter'].sum().diff().sort_values(ascending = True)
popular_code.head()
# Out:
# hour  postal_code
# 7     92120         -43.0
# 6     78000         -38.0
# 20    94110         -38.0
# 13    92100         -35.0
# 11    75018         -32.0
# Name: bluecar_counter, dtype: float64

# %% [markdown]
# ##most popular hour for utilib_counter

# %%
#for incase of utilib_counter the most popular postal code
popular_code = Autolib.groupby(['hour','postal_code'])['utilib_counter'].sum().diff().sort_values(ascending = True)
popular_code.head()
# Out:
# hour  postal_code
# 22    92100         -3.0
# 6     78000         -3.0
# 8     75016         -3.0
# 6     75012         -3.0
# 19    75018         -3.0
# Name: utilib_counter, dtype: float64

# %%
Autolib.head()
# Out:
#                             address  cars  ...  bluecar_Diff  total_cars
# 0               2 Avenue de Suffren     0  ...           NaN           0
# 4330                1 rue de Sevran     0  ...           0.0           0
# 1180         137 Rue des Pyr̩n̩es     0  ...           0.0           0
# 4328                31 avenue Hoche     0  ...           0.0           0
# 4234  24 rue du Pont Louis-Philippe     0  ...           0.0           0
#
# [5 rows x 27 columns]

# %% [markdown]
# ##most popular postal code for utilib_1.4_counter

# %%
#for incasse of utilib_1.4_counter 
popular_code = Autolib.groupby(['hour','postal_code'])['utilib_1.4_counter'].sum().diff().sort_values(ascending = True)
popular_code.head()
# Out:
# hour  postal_code
# 21    75015         -6.0
# 0     92370         -6.0
# 22    92100         -4.0
# 17    91370         -4.0
# 14    75002         -4.0
# Name: utilib_1.4_counter, dtype: float64
